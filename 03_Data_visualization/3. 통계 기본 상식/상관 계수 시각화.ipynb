# %% [markdown]
# ### corr()이 실행이 안될때
# 이전 버전에서는 디폴트가 True였는데, 2.1 버전 정도부터 기본값이 바뀌었다고 해요.
# 때문에 데이터 자료형이 범주형, 수치형 모두 섞여 있는 데이터 프레임의 경우, 수치형 변수만 선택할 수 있게 해주는 numeric_only 파라미터를 True로 지정해줘야 잘 작동합니다.
# df.corr(numeric_only=True)

# %% [markdown]
# ## 상관계수 시각화
#
# 학생들의 시험 점수 데이터가 있습니다. 데이터 사이의 상관 계수를 살펴봅시다.
#
# DataFrame의 corr() 메소드를 사용하면, 숫자 데이터 사이의 상관 계수를 보여 줍니다.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib
import traceback

df = pd.read_csv('data/exam.csv')

df.corr(numeric_only=True)
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %% [markdown]
# 상관 계수도 DataFrame 형태로 출력됩니다.
# 하지만 숫자가 많다보니 한눈에 잘 들어오지 않을 수 있는데요. 이럴 때 히트맵을 사용합니다.
#
# 히트맵은 상관 계수를 시각화하는 대표적인 방법입니다. 상관 계수는 시각화해서 보는 경우가 많습니다.
# Seaborn을 이용하면 히트맵을 그릴 수 있습니다.
#
# 상관 계수의 결과를 Seaborn의 heatmap 메소드에 넘겨주면 됩니다.

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

df = pd.read_csv('data/exam.csv')

sns.heatmap(df.corr(numeric_only=True))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 7
#       3 import seaborn as sns
#       5 df = pd.read_csv('data/exam.csv')
# ----> 7 sns.heatmap(df.corr(numeric_only=True))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/matrix.py:528, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     526 if square:
#     527     ax.set_aspect("equal")
# --> 528 plotter.plot(ax, cbar_ax, kwargs)
#     529 return ax
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/matrix.py:303, in _HeatMapper.plot(self, ax, cax, kws)
#     301 # Add row and column labels
#     302 if isinstance(self.xticks, string_types) and self.xticks == "auto":
# --> 303     xticks, xticklabels = self._auto_ticks(ax, self.xticklabels, 0)
#     304 else:
#     305     xticks, xticklabels = self.xticks, self.xticklabels
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/matrix.py:268, in _HeatMapper._auto_ticks(self, ax, labels, axis)
#     266 axis = [ax.xaxis, ax.yaxis][axis]
#     267 tick, = axis.set_ticks([0])
# --> 268 fontsize = tick.label.get_size()
#     269 max_ticks = int(size // (fontsize / 72))
#     270 if max_ticks < 1:
#
# AttributeError: 'XTick' object has no attribute 'label'

# %% [markdown]
# 색이 밝을수록 상관 계수가 더 높다는 의미입니다.
# 읽기 점수(reading score)와 쓰기 점수(writing score) 사이의 상관 관계가 가장 강하다는 것을 한 눈에 알 수 있네요.
#
# annot=True 옵션을 추가해주면, 색상 뿐 아니라 숫자도 함께 보여줍니다.

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

df = pd.read_csv('data/exam.csv')

sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 7
#       3 import seaborn as sns
#       5 df = pd.read_csv('data/exam.csv')
# ----> 7 sns.heatmap(df.corr(numeric_only=True), annot=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/matrix.py:528, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     526 if square:
#     527     ax.set_aspect("equal")
# --> 528 plotter.plot(ax, cbar_ax, kwargs)
#     529 return ax
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/matrix.py:303, in _HeatMapper.plot(self, ax, cax, kws)
#     301 # Add row and column labels
#     302 if isinstance(self.xticks, string_types) and self.xticks == "auto":
# --> 303     xticks, xticklabels = self._auto_ticks(ax, self.xticklabels, 0)
#     304 else:
#     305     xticks, xticklabels = self.xticks, self.xticklabels
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/matrix.py:268, in _HeatMapper._auto_ticks(self, ax, labels, axis)
#     266 axis = [ax.xaxis, ax.yaxis][axis]
#     267 tick, = axis.set_ticks([0])
# --> 268 fontsize = tick.label.get_size()
#     269 max_ticks = int(size // (fontsize / 72))
#     270 if max_ticks < 1:
#
# AttributeError: 'XTick' object has no attribute 'label'
