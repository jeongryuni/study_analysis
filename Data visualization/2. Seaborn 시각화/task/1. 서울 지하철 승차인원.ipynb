# %% [markdown]
# ### 실습 설명
# 서울 지하철 역에 대한 승차인원 및 하차인원 정보가 주어져 있습니다.
#
# 승차인원에 대한 KDE Plot을 그려 보세요.

# %%
import seaborn as sns
import pandas as pd

# %%
subway = pd.read_csv('data/subway.csv')
subway.head()
# Out:
#   line station    in   out
# 0  중앙선      지평    37    28
# 1  중앙선      용문  2064  2103
# 2  중앙선      원덕   375   357
# 3  중앙선      양평  4338  4378
# 4  중앙선      오빈   321   321

# %%
subway['in']
# Out:
# 0         37
# 1       2064
# 2        375
# 3       4338
# 4        321
#        ...
# 586    31245
# 587    38099
# 588    52310
# 589    29150
# 590    58391
# Name: in, Length: 591, dtype: int64

# %%
subway['in'].value_counts()
# Out:
# in
# 4645     2
# 8066     2
# 13618    1
# 13575    1
# 8199     1
#         ..
# 3257     1
# 2252     1
# 1595     1
# 3821     1
# 58391    1
# Name: count, Length: 589, dtype: int64

# %%
subway['in'].value_counts().sort_values()
# Out:
# in
# 5161     1
# 6160     1
# 8154     1
# 1804     1
# 375      1
#         ..
# 31245    1
# 38099    1
# 30269    1
# 8066     2
# 4645     2
# Name: count, Length: 589, dtype: int64

# %%
subway['in'].value_counts().sort_values().plot()
# Out:
# <Axes: xlabel='in'>

# %%
sns.kdeplot(subway['in'])
# Out:
# <Axes: >
