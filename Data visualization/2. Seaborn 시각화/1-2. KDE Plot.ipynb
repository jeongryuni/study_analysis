# %% [markdown]
# ## KDE (Kernel Density Estimation)
#
# -- KDE를 사용하면 어느정도 추측해서 부드러운 곡선으로 만듬

# %%
# !pip3 install seaborn==0.9.0
# Out:
# Requirement already satisfied: seaborn==0.9.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.9.0)
# Requirement already satisfied: matplotlib>=1.4.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from seaborn==0.9.0) (3.8.4)
# Requirement already satisfied: numpy>=1.9.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from seaborn==0.9.0) (1.23.1)
# Requirement already satisfied: pandas>=0.15.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from seaborn==0.9.0) (2.1.3)
# Requirement already satisfied: scipy>=0.14.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from seaborn==0.9.0) (1.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (23.2)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=0.15.2->seaborn==0.9.0) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=0.15.2->seaborn==0.9.0) (2023.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->seaborn==0.9.0) (1.16.0)

# %%
import pandas as pd
import seaborn as sns

# %%
body_df = pd.read_csv('data/body.csv', index_col=0)
body_df.head()
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0

# %%
body_df['Height']
# Out:
# Number
# 1       176.0
# 2       175.3
# 3       168.6
# 4       168.1
# 5       175.3
#         ...
# 996     171.8
# 997     171.5
# 998     177.9
# 999     174.4
# 1000    173.5
# Name: Height, Length: 1000, dtype: float64

# %%
body_df['Height'].value_counts()
# Out:
# Height
# 174.9    13
# 172.5    13
# 173.2    12
# 175.3    12
# 175.2    12
#          ..
# 160.2     1
# 188.2     1
# 162.0     1
# 185.1     1
# 184.4     1
# Name: count, Length: 262, dtype: int64

# %%
# 인덱스 순으로 정렬
body_df['Height'].value_counts().sort_index()
# Out:
# Height
# 154.4    1
# 155.5    1
# 157.4    1
# 157.8    1
# 158.0    1
#         ..
# 190.3    1
# 191.2    1
# 191.8    1
# 192.4    1
# 193.1    1
# Name: count, Length: 262, dtype: int64

# %%
body_df['Height'].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='Height'>

# %%
# Seaborn 사용
sns.kdeplot(body_df['Height'])
# Out:
# <Axes: >

# %%
# Seaborn 사용
# bw를 이용해 수준 설정
sns.kdeplot(body_df['Height'], bw = 0.05)
# Out:
# <Axes: >
