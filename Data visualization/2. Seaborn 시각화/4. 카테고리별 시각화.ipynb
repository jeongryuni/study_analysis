# %%
import seaborn as sns
import pandas as pd

# %%
laptops_df = pd.read_csv('data/laptops.csv')
laptops_df.head()
# Out:
#    brand             model  ram hd_type  hd_size  screen_size   price  \
# 0   Dell  Inspiron 15-3567    4     hdd     1024         15.6   40000
# 1  Apple       MacBook Air    8     ssd      128         13.3   55499
# 2  Apple       MacBook Air    8     ssd      256         13.3   71500
# 3  Apple       MacBook Pro    8     ssd      128         13.3   96890
# 4  Apple       MacBook Pro    8     ssd      256         13.3  112666
#
#   processor_brand processor_model  clock_speed graphic_card_brand  \
# 0           intel              i5          2.5              intel
# 1           intel              i5          1.8              intel
# 2           intel              i5          1.8              intel
# 3           intel              i5          2.3              intel
# 4           intel              i5          2.3              intel
#
#    graphic_card_size     os  weight comments
# 0                NaN  linux    2.50      NaN
# 1                2.0    mac    1.35      NaN
# 2                2.0    mac    1.35      NaN
# 3                2.0    mac    3.02      NaN
# 4                2.0    mac    3.02      NaN

# %%
laptops_df['os'].unique()
# Out:
# array(['linux', 'mac', 'windows'], dtype=object)

# %%
# 리눅스가 윈도우랑 맥보다는 저렴하다.
# 윈도우랑 맥은 리눅스에 비해 가격이 분산되어 있다.
sns.catplot(data=laptops_df, x='os', y='price', kind='box')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/categorical.py:330: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return pd.api.types.is_categorical_dtype(s)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/categorical.py:330: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return pd.api.types.is_categorical_dtype(s)

# %%
# 각 os에 데이터의 개수를 몰라 플롯들을 신뢰할 수 잆다.
sns.catplot(data=laptops_df, x='os', y='price', kind='violin')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/categorical.py:330: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return pd.api.types.is_categorical_dtype(s)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/categorical.py:330: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return pd.api.types.is_categorical_dtype(s)

# %%
# 데이터를 하나하나 볼 수 있다.
sns.catplot(data=laptops_df, x='os', y='price', kind='strip')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/categorical.py:330: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return pd.api.types.is_categorical_dtype(s)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/categorical.py:330: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return pd.api.types.is_categorical_dtype(s)

# %%
laptops_df['processor_brand'].unique()
# Out:
# array(['intel', 'amd'], dtype=object)

# %%
# hue는 프로세서 브랜드에 따라 색을 다르게 해주는 역할
# 점이 많이 몰려있으면 보기 불편함
sns.catplot(data=laptops_df, x='os', y='price', kind='strip', hue='processor_brand')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/categorical.py:330: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return pd.api.types.is_categorical_dtype(s)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/categorical.py:330: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return pd.api.types.is_categorical_dtype(s)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # hue는 프로세서 브랜드에 따라 색을 다르게 해주는 역할
# ----> 2 sns.catplot(data=laptops_df, x='os', y='price', kind='strip', hue='processor_brand')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/categorical.py:3766, in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3764 if legend and (hue is not None) and (hue not in [x, row, col]):
#    3765     hue_order = list(map(utils.to_utf8, hue_order))
# -> 3766     g.add_legend(title=hue, label_order=hue_order)
#    3768 return g
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/axisgrid.py:87, in Grid.add_legend(self, legend_data, title, label_order, **kwargs)
#      84 kwargs.setdefault("frameon", False)
#      86 # Draw a full-figure legend outside the grid
# ---> 87 figlegend = self.fig.legend(handles, label_order, "center right",
#      88                             **kwargs)
#      89 self._legend = figlegend
#      90 figlegend.set_title(title, prop={"size": title_size})
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/figure.py:1146, in FigureBase.legend(self, *args, **kwargs)
#    1035 @_docstring.dedent_interpd
#    1036 def legend(self, *args, **kwargs):
#    1037     """
#    1038     Place a legend on the figure.
#    1039
#    (...)
#    1143     :ref:`legend_guide` for details.
#    1144     """
# -> 1146     handles, labels, kwargs = mlegend._parse_legend_args(self.axes, *args, **kwargs)
#    1147     # explicitly set the bbox transform if the user hasn't.
#    1148     kwargs.setdefault("bbox_transform", self.transSubfigure)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/legend.py:1382, in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1379     handles, labels = args[:2]
#    1381 else:
# -> 1382     raise _api.nargs_error('legend', '0-2', len(args))
#    1384 return handles, labels, kwargs
#
# TypeError: legend() takes 0-2 positional arguments but 3 were given

# %%
# hue는 프로세서 브랜드에 따라 색을 다르게 해주는 역할
# 점들이 뭉쳐있지 않고 펼쳐짐
sns.catplot(data=laptops_df, x='os', y='price', kind='swarm', hue='processor_brand')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/categorical.py:330: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return pd.api.types.is_categorical_dtype(s)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/categorical.py:330: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return pd.api.types.is_categorical_dtype(s)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # hue는 프로세서 브랜드에 따라 색을 다르게 해주는 역할
# ----> 2 sns.catplot(data=laptops_df, x='os', y='price', kind='swarm', hue='processor_brand')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/categorical.py:3766, in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3764 if legend and (hue is not None) and (hue not in [x, row, col]):
#    3765     hue_order = list(map(utils.to_utf8, hue_order))
# -> 3766     g.add_legend(title=hue, label_order=hue_order)
#    3768 return g
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/axisgrid.py:87, in Grid.add_legend(self, legend_data, title, label_order, **kwargs)
#      84 kwargs.setdefault("frameon", False)
#      86 # Draw a full-figure legend outside the grid
# ---> 87 figlegend = self.fig.legend(handles, label_order, "center right",
#      88                             **kwargs)
#      89 self._legend = figlegend
#      90 figlegend.set_title(title, prop={"size": title_size})
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/figure.py:1146, in FigureBase.legend(self, *args, **kwargs)
#    1035 @_docstring.dedent_interpd
#    1036 def legend(self, *args, **kwargs):
#    1037     """
#    1038     Place a legend on the figure.
#    1039
#    (...)
#    1143     :ref:`legend_guide` for details.
#    1144     """
# -> 1146     handles, labels, kwargs = mlegend._parse_legend_args(self.axes, *args, **kwargs)
#    1147     # explicitly set the bbox transform if the user hasn't.
#    1148     kwargs.setdefault("bbox_transform", self.transSubfigure)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/legend.py:1382, in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1379     handles, labels = args[:2]
#    1381 else:
# -> 1382     raise _api.nargs_error('legend', '0-2', len(args))
#    1384 return handles, labels, kwargs
#
# TypeError: legend() takes 0-2 positional arguments but 3 were given
